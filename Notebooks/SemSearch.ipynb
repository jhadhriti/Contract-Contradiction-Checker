# %%
# Install the Client library (Semantic Retriever is only supported for versions >0.4.0)
# !pip3 install -U google.ai.generativelanguage
# Out:
# Collecting google.ai.generativelanguage
#   Downloading google_ai_generativelanguage-0.6.7-py3-none-any.whl (719 kB)
#      -------------------------------------- 719.2/719.2 kB 3.0 MB/s eta 0:00:00
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1
#   Downloading google_api_core-2.19.1-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.4/139.4 kB 2.8 MB/s eta 0:00:00
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1
#   Downloading google_auth-2.32.0-py2.py3-none-any.whl (195 kB)
#      -------------------------------------- 195.5/195.5 kB 2.9 MB/s eta 0:00:00
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.24.0-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.1/50.1 kB ? eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google.ai.generativelanguage) (4.25.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (1.63.2)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (1.64.1)
# Collecting grpcio-status<2.0.dev0,>=1.33.2
#   Downloading grpcio_status-1.64.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google.ai.generativelanguage) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google.ai.generativelanguage) (0.4.0)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2
#   Downloading protobuf-5.27.2-cp310-abi3-win_amd64.whl (426 kB)
#      -------------------------------------- 426.9/426.9 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google.ai.generativelanguage) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google.ai.generativelanguage) (2024.7.4)
# Installing collected packages: rsa, protobuf, proto-plus, google-auth, grpcio-status, google-api-core, google.ai.generativelanguage
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# Successfully installed google-api-core-2.19.1 google-auth-2.32.0 google.ai.generativelanguage-0.6.7 grpcio-status-1.64.1 proto-plus-1.24.0 protobuf-5.27.2 rsa-4.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.25.0 requires protobuf<5.0,>=3.19, but you have protobuf 5.27.2 which is incompatible.
#
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U google-auth-oauthlib
# Out:
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-auth-oauthlib) (2.32.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.0.0 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2024.7.4)
# Installing collected packages: oauthlib, requests-oauthlib, google-auth-oauthlib
# Successfully installed google-auth-oauthlib-1.2.1 oauthlib-3.2.2 requests-oauthlib-2.0.0
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
service_account_file_name = '../contradiction-checker-583a085c67ca.json'

from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(service_account_file_name)

scoped_credentials = credentials.with_scopes(
    ['https://www.googleapis.com/auth/cloud-platform', 'https://www.googleapis.com/auth/generative-language.retriever'])

# %%
import google.ai.generativelanguage as glm
generative_service_client = glm.GenerativeServiceClient(credentials=scoped_credentials)
retriever_service_client = glm.RetrieverServiceClient(credentials=scoped_credentials)
permission_service_client = glm.PermissionServiceClient(credentials=scoped_credentials)

# %%
example_corpus = glm.Corpus(display_name="Google for Developers Blog")
create_corpus_request = glm.CreateCorpusRequest(corpus=example_corpus)

# Make the request
create_corpus_response = retriever_service_client.create_corpus(create_corpus_request)

# Set the `corpus_resource_name` for subsequent sections.
corpus_resource_name = create_corpus_response.name
print(create_corpus_response)
# Out:
# name: "corpora/google-for-developers-blog-iiiol6kl1i8x"
# display_name: "Google for Developers Blog"
# create_time {
#   seconds: 1720534394
#   nanos: 427855000
# }
# update_time {
#   seconds: 1720534394
#   nanos: 427855000
# }

# %%
get_corpus_request = glm.GetCorpusRequest(name=corpus_resource_name)

# Make the request
get_corpus_response = retriever_service_client.get_corpus(get_corpus_request)

# Print the response
print(get_corpus_response)
# Out:
# name: "corpora/google-for-developers-blog-iiiol6kl1i8x"
# display_name: "Google for Developers Blog"
# create_time {
#   seconds: 1720534394
#   nanos: 427855000
# }
# update_time {
#   seconds: 1720534394
#   nanos: 427855000
# }

# %%
# Create a document with a custom display name.
example_document = glm.Document(display_name="Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development")

# Add metadata.
# Metadata also supports numeric values not specified here
document_metadata = [
    glm.CustomMetadata(key="url", string_value="https://developers.googleblog.com/2023/08/introducing-project-idx-experiment-to-improve-full-stack-multiplatform-app-development.html")]
example_document.custom_metadata.extend(document_metadata)

# Make the request
# corpus_resource_name is a variable set in the "Create a corpus" section.
create_document_request = glm.CreateDocumentRequest(parent=corpus_resource_name, document=example_document)
create_document_response = retriever_service_client.create_document(create_document_request)

# Set the `document_resource_name` for subsequent sections.
document_resource_name = create_document_response.name
print(create_document_response)
# Out:
# name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3"
# display_name: "Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development"
# custom_metadata {
#   key: "url"
#   string_value: "https://developers.googleblog.com/2023/08/introducing-project-idx-experiment-to-improve-full-stack-multiplatform-app-development.html"
# }
# update_time {
#   seconds: 1720534528
#   nanos: 859633000
# }
# create_time {
#   seconds: 1720534528
#   nanos: 859633000
# }

# %%
get_document_request = glm.GetDocumentRequest(name=document_resource_name)

# Make the request
# document_resource_name is a variable set in the "Create a document" section.
get_document_response = retriever_service_client.get_document(get_document_request)

# Print the response
print(get_document_response)
# Out:
# name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3"
# display_name: "Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development"
# custom_metadata {
#   key: "url"
#   string_value: "https://developers.googleblog.com/2023/08/introducing-project-idx-experiment-to-improve-full-stack-multiplatform-app-development.html"
# }
# update_time {
#   seconds: 1720534528
#   nanos: 859633000
# }
# create_time {
#   seconds: 1720534528
#   nanos: 859633000
# }

# %%
# !pip install google-labs-html-chunker

from google_labs_html_chunker.html_chunker import HtmlChunker

from urllib.request import urlopen
# Out:
# Collecting google-labs-html-chunker
#   Downloading google_labs_html_chunker-0.0.5-py3-none-any.whl (5.9 kB)
# Collecting beautifulsoup4>=4.12.2
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 kB 2.2 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: six>=1.9 in c:\users\divya\desktop\divyams_computer_folder\python files\iitisoc\repo\contradiction-let-me-check\venv\lib\site-packages (from html5lib>=1.1->google-labs-html-chunker) (1.16.0)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, soupsieve, html5lib, beautifulsoup4, google-labs-html-chunker
# Successfully installed beautifulsoup4-4.12.3 google-labs-html-chunker-0.0.5 html5lib-1.1 soupsieve-2.5 webencodings-0.5.1
# [notice] A new release of pip available: 22.3.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
with(urlopen("https://developers.googleblog.com/2023/08/introducing-project-idx-experiment-to-improve-full-stack-multiplatform-app-development.html")) as f:
  html = f.read().decode("utf-8")

# %%
# Chunk the file using HtmlChunker
chunker = HtmlChunker(
    max_words_per_aggregate_passage=200,
    greedily_aggregate_sibling_nodes=True,
    html_tags_to_exclude={"noscript", "script", "style"},
)
passages = chunker.chunk(html)
print(passages)


# Create `Chunk` entities.
chunks = []
for passage in passages:
    chunk = glm.Chunk(data={'string_value': passage})
    # Optionally, you can add metadata to a chunk
    chunk.custom_metadata.append(glm.CustomMetadata(key="tags",
                                                    string_list_value=glm.StringList(
                                                        values=["Google For Developers", "Project IDX", "Blog", "Announcement"])))
    chunk.custom_metadata.append(glm.CustomMetadata(key="chunking_strategy",
                                                    string_value="greedily_aggregate_sibling_nodes"))
    chunk.custom_metadata.append(glm.CustomMetadata(key = "publish_date",
                                                    numeric_value = 20230808))
    chunks.append(chunk)
print(chunks)
# Out:
# ['Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development\n            \n            \n            \n            - Google Developers Blog', 'Products Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Solutions Events Learn Community Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories Developer Program Blog Search English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文', 'Products More Solutions Events Learn Community More Developer Program Blog Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文', 'Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development AUG 08, 2023 Bre Arder UX Research Lead Kirupa Chinnathambi Product Lead Ashwin Raghav Mohan Ganesh Engineering Lead Erin Kidwell Director of Engineering Roman Nurik Design Lead Share Facebook Twitter LinkedIn Mail', "These days, getting an app from zero to production – especially one that works well across mobile, web, and desktop platforms – can feel like building a Rube Goldberg machine. You’ve got to navigate an endless sea of complexity, duct-taping together a tech stack that'll help you bootstrap, compile, test, deploy, and monitor your apps. While Google’s been working on making multiplatform app development easier for years – from Angular and Flutter to Google Cloud and Firebase – it feels like there’s even more we can do to make the entire multiplatform app development workflow faster and more frictionless . So several months ago, a few of us got together and started experimenting. And today, we’re excited to share a very early look at our experiment, which we’re calling Project IDX .", "Sorry, your browser doesn't support playback for this video", 'Project IDX is a browser-based development experience built on Google Cloud and powered by Codey , a foundational AI model trained on code and built on PaLM 2. It’s designed to make it easier to build, manage and deploy full-stack web and multiplatform applications, with popular frameworks and languages. Project IDX is also built on Code OSS , so it should feel familiar no matter what you’re building. A big part of why we’re sharing Project IDX today is we’d love to hear from the broader developer community on what could help you work even faster. In the meantime, here’s a preview of what’s possible today with Project IDX. Get to work quickly, from anywhere At the heart of Project IDX is our conviction that you should be able to develop from anywhere, on any device, with the full fidelity of local development. Every Project IDX workspace has the full capabilities of a Linux-based VM, paired with the universal access that comes with being hosted in the cloud, in a datacenter near you.', "Sorry, your browser doesn't support playback for this video", 'Import your existing app, or start something new Project IDX lets you import your existing projects from GitHub so you can pick up right where you left off. You can also create new projects, with pre-baked templates for popular frameworks, including Angular, Flutter, Next.js, React, Svelte, Vu ...
# [data {
#   string_value: "Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development\n            \n            \n            \n            - Google Developers Blog"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Products Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Solutions Events Learn Community Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories Developer Program Blog Search English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Products More Solutions Events Learn Community More Developer Program Blog Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development AUG 08, 2023 Bre Arder UX Research Lead Kirupa Chinnathambi Product Lead Ashwin Raghav Mohan Ganesh Engineering Lead Erin Kidwell Director of Engineering Roman Nurik Design Lead Share Facebook Twitter LinkedIn Mail"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "These days, getting an app from zero to production – especially one that works well across mobile, web, and desktop platforms – can feel like building a Rube Goldberg machine. You’ve got to navigate an endless sea of complexity, duct-taping together a tech stack that\'ll help you bootstrap, compile, test, deploy, and monitor your apps. While Google’s been working on making multiplatform app development easier for years – from Angular and Flutter to Google Cloud and Firebase – it feels like there’s even more we can do to make the entire multiplatform app development workflow faster and more frictionless . So several months ago, a few of us got together and started experimenting. And today, we’re excited to share a very early look at our experiment, which we’re calling Project IDX ."
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Sorry, your browser doesn\'t support playback for this video"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Project IDX is a browser-based development experience built on Google Cloud and powered by Codey , a foundational AI model trained on code and built on PaLM 2. It’s designed to make it easier to build, manage and deploy full-stack web and multiplatform applications, with popular frameworks and languages. Project IDX is also built on Code OSS , so it should feel familiar no matter what you’re building. A big part of why we’re sharing Project IDX today is we’d love to hear from the broader developer community on what could help you work even faster. In the meantime, here’s a preview of what’s possible today with Project IDX. Get to work quickly, from anywhere At the heart of Project IDX is our conviction that you should be able to develop from anywhere, on any device, with the full fidelity of local development. Every Project IDX workspace has the full capabilities of a Linux-based VM, paired with the universal access that comes with being hosted in the cloud, in a datacenter near you."
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Sorry, your browser doesn\'t support playback for this video"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Import your existing app, or start something new Project IDX lets you import your existing projects from GitHub so you can pick up right where you left off. You can also create new projects, with pre-baked templates for popular frameworks, including Angular, Flutter, Next.js, React, Svelte, Vue, and languages such as JavaScript, Dart, and (coming soon) Python, Go, and more. We’re also actively working to add first-class support for more project types and frameworks. If you have any suggestions, we’d love your feedback on which stacks to support."
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Preview your app across platforms Creating successful apps today means optimizing your app design and behavior across platforms, and previewing your apps just as your users would see them. To make this easier, Project IDX includes a built-in web preview and, coming soon, a fully-configured Android emulator and an embedded iOS simulator, all available directly in the browser."
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Sorry, your browser doesn\'t support playback for this video"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Help from AI We spend a lot of time writing code, and recent advances in AI have created big opportunities to make that time more productive. With Project IDX, we’re exploring how Google’s innovations in AI — including the Codey and PaLM 2 models powering Studio Bot in Android Studio , Duet in Google Cloud and more – can help you not only write code faster, but also write higher-quality code. Currently, Project IDX has smart code completion, an assistive chatbot, and contextual code actions like “add comments” and “explain this code”. Our AI capabilities are in their very early days, and we’re working on making IDX AI even better at helping you as you work."
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Sorry, your browser doesn\'t support playback for this video"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Publish to the web with Firebase Hosting Finally, a common pain point in getting your app into production is deploying it. We’ve made this easier by integrating Firebase Hosting , making it possible to deploy a shareable preview of your web app, or deploy to production with a fast, secure, and global hosting platform, with just a few clicks. And because Firebase Hosting supports dynamic backends, powered by Cloud Functions, this works great for full-stack frameworks like Next.js."
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Let’s build Project IDX together We shared how we think Project IDX can start to make multiplatform app development better, along with some strides we’ve started making in these areas. But we are just at the beginning of this journey to improve the end-to-end development workflow, and we can only make good on this vision with your help. So with that, we’d like to share an early version of Project IDX with you — rough edges and all — to iterate on what’s working well and what could be even better for your app team’s workflow. To join us on our journey, visit our website to sign up and be one of the first to try Project IDX. As for what’s next, we’re continuously working on adding new capabilities and addressing your feedback. We’re already working on new collaboration features, as we know how important those are in this hybrid work world, as well as deeper framework integrations and more personalized/contextual AI. Please share your feature requests with us as well!"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "posted in: AI Explore App Development multi-platform Previous Next Related Posts Gemma AI Announcements Fine-tuning Gemma 2 with Keras - and an update from Hugging Face June 27, 2024 Mobile Web Announcements Bringing the I/O magic to Berlin June 27, 2024"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Connect Blog Instagram LinkedIn Twitter YouTube Programs Women Techmakers Google Developer Groups Google Developer Experts Accelerators Google Developer Student Clubs Developer consoles Google API Console Google Cloud Platform Console Google Play Console Firebase Console Actions on Google Console Cast SDK Developer Console Chrome Web Store Dashboard"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# , data {
#   string_value: "Android Chrome Firebase Google Cloud Platform All products Manage cookies Terms Privacy English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
# }
# custom_metadata {
#   key: "tags"
#   string_list_value {
#     values: "Google For Developers"
#     values: "Project IDX"
#     values: "Blog"
#     values: "Announcement"
#   }
# }
# custom_metadata {
#   key: "chunking_strategy"
#   string_value: "greedily_aggregate_sibling_nodes"
# }
# custom_metadata {
#   key: "publish_date"
#   numeric_value: 20230808
# }
# ]

# %%
# Option 1: Use HtmlChunker in the section above.
# `chunks` is the variable set from the section above.
create_chunk_requests = []
for chunk in chunks:
  create_chunk_requests.append(glm.CreateChunkRequest(parent=document_resource_name, chunk=chunk))

# Make the request
request = glm.BatchCreateChunksRequest(parent=document_resource_name, requests=create_chunk_requests)
response = retriever_service_client.batch_create_chunks(request)
print(response)
# Out:
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/zy2f8m98kbux"
#   data {
#     string_value: "Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development\n            \n            \n            \n            - Google Developers Blog"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/jy8pcszi20h3"
#   data {
#     string_value: "Products Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Solutions Events Learn Community Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories Developer Program Blog Search English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/6tvx8kgacs0d"
#   data {
#     string_value: "Products More Solutions Events Learn Community More Developer Program Blog Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/vj65fefy38bi"
#   data {
#     string_value: "Introducing Project IDX, An Experiment to Improve Full-stack, Multiplatform App Development AUG 08, 2023 Bre Arder UX Research Lead Kirupa Chinnathambi Product Lead Ashwin Raghav Mohan Ganesh Engineering Lead Erin Kidwell Director of Engineering Roman Nurik Design Lead Share Facebook Twitter LinkedIn Mail"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/hkju6fmoxocd"
#   data {
#     string_value: "These days, getting an app from zero to production – especially one that works well across mobile, web, and desktop platforms – can feel like building a Rube Goldberg machine. You’ve got to navigate an endless sea of complexity, duct-taping together a tech stack that\'ll help you bootstrap, compile, test, deploy, and monitor your apps. While Google’s been working on making multiplatform app development easier for years – from Angular and Flutter to Google Cloud and Firebase – it feels like there’s even more we can do to make the entire multiplatform app development workflow faster and more frictionless . So several months ago, a few of us got together and started experimenting. And today, we’re excited to share a very early look at our experiment, which we’re calling Project IDX ."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/8c9p6upvq0m1"
#   data {
#     string_value: "Sorry, your browser doesn\'t support playback for this video"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/hpbpzavvgdof"
#   data {
#     string_value: "Project IDX is a browser-based development experience built on Google Cloud and powered by Codey , a foundational AI model trained on code and built on PaLM 2. It’s designed to make it easier to build, manage and deploy full-stack web and multiplatform applications, with popular frameworks and languages. Project IDX is also built on Code OSS , so it should feel familiar no matter what you’re building. A big part of why we’re sharing Project IDX today is we’d love to hear from the broader developer community on what could help you work even faster. In the meantime, here’s a preview of what’s possible today with Project IDX. Get to work quickly, from anywhere At the heart of Project IDX is our conviction that you should be able to develop from anywhere, on any device, with the full fidelity of local development. Every Project IDX workspace has the full capabilities of a Linux-based VM, paired with the universal access that comes with being hosted in the cloud, in a datacenter near you."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/dmmm49ujud3o"
#   data {
#     string_value: "Sorry, your browser doesn\'t support playback for this video"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/jxzcxeymxbz5"
#   data {
#     string_value: "Import your existing app, or start something new Project IDX lets you import your existing projects from GitHub so you can pick up right where you left off. You can also create new projects, with pre-baked templates for popular frameworks, including Angular, Flutter, Next.js, React, Svelte, Vue, and languages such as JavaScript, Dart, and (coming soon) Python, Go, and more. We’re also actively working to add first-class support for more project types and frameworks. If you have any suggestions, we’d love your feedback on which stacks to support."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/lyrjw33uczz0"
#   data {
#     string_value: "Preview your app across platforms Creating successful apps today means optimizing your app design and behavior across platforms, and previewing your apps just as your users would see them. To make this easier, Project IDX includes a built-in web preview and, coming soon, a fully-configured Android emulator and an embedded iOS simulator, all available directly in the browser."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/t55v3oerd1ei"
#   data {
#     string_value: "Sorry, your browser doesn\'t support playback for this video"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/bu4fum8h35tc"
#   data {
#     string_value: "Help from AI We spend a lot of time writing code, and recent advances in AI have created big opportunities to make that time more productive. With Project IDX, we’re exploring how Google’s innovations in AI — including the Codey and PaLM 2 models powering Studio Bot in Android Studio , Duet in Google Cloud and more – can help you not only write code faster, but also write higher-quality code. Currently, Project IDX has smart code completion, an assistive chatbot, and contextual code actions like “add comments” and “explain this code”. Our AI capabilities are in their very early days, and we’re working on making IDX AI even better at helping you as you work."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/4z8b1269fayt"
#   data {
#     string_value: "Sorry, your browser doesn\'t support playback for this video"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/lzwkkpn8dgnl"
#   data {
#     string_value: "Publish to the web with Firebase Hosting Finally, a common pain point in getting your app into production is deploying it. We’ve made this easier by integrating Firebase Hosting , making it possible to deploy a shareable preview of your web app, or deploy to production with a fast, secure, and global hosting platform, with just a few clicks. And because Firebase Hosting supports dynamic backends, powered by Cloud Functions, this works great for full-stack frameworks like Next.js."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/ygr31a3ebd51"
#   data {
#     string_value: "Let’s build Project IDX together We shared how we think Project IDX can start to make multiplatform app development better, along with some strides we’ve started making in these areas. But we are just at the beginning of this journey to improve the end-to-end development workflow, and we can only make good on this vision with your help. So with that, we’d like to share an early version of Project IDX with you — rough edges and all — to iterate on what’s working well and what could be even better for your app team’s workflow. To join us on our journey, visit our website to sign up and be one of the first to try Project IDX. As for what’s next, we’re continuously working on adding new capabilities and addressing your feedback. We’re already working on new collaboration features, as we know how important those are in this hybrid work world, as well as deeper framework integrations and more personalized/contextual AI. Please share your feature requests with us as well!"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/gg9c2o5cclmx"
#   data {
#     string_value: "posted in: AI Explore App Development multi-platform Previous Next Related Posts Gemma AI Announcements Fine-tuning Gemma 2 with Keras - and an update from Hugging Face June 27, 2024 Mobile Web Announcements Bringing the I/O magic to Berlin June 27, 2024"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/mhmi0dlnca04"
#   data {
#     string_value: "Connect Blog Instagram LinkedIn Twitter YouTube Programs Women Techmakers Google Developer Groups Google Developer Experts Accelerators Google Developer Student Clubs Developer consoles Google API Console Google Cloud Platform Console Google Play Console Firebase Console Actions on Google Console Cast SDK Developer Console Chrome Web Store Dashboard"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/vqokj4eq2lqb"
#   data {
#     string_value: "Android Chrome Firebase Google Cloud Platform All products Manage cookies Terms Privacy English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Project IDX"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "greedily_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20230808
#   }
#   state: STATE_PENDING_PROCESSING
# }

# %%
# Add up to 100 CreateChunk requests per batch request.
# document_resource_name is a variable set in the "Create a document" section.
chunks = []
chunk_1 = glm.Chunk(data={'string_value': "Chunks support user specified metadata."})
chunk_1.custom_metadata.append(glm.CustomMetadata(key="section",
                                                  string_value="Custom metadata filters"))
chunk_2 = glm.Chunk(data={'string_value': "The maximum number of metadata supported is 20"})
chunk_2.custom_metadata.append(glm.CustomMetadata(key = "num_keys",
                                                  numeric_value = 20))
chunks = [chunk_1, chunk_2]
create_chunk_requests = []
for chunk in chunks:
  create_chunk_requests.append(glm.CreateChunkRequest(parent=document_resource_name, chunk=chunk))

# Make the request
request = glm.BatchCreateChunksRequest(parent=document_resource_name, requests=create_chunk_requests)
response = retriever_service_client.batch_create_chunks(request)
print(response)
# Out:
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/v43tyvokpegt"
#   data {
#     string_value: "Chunks support user specified metadata."
#   }
#   custom_metadata {
#     key: "section"
#     string_value: "Custom metadata filters"
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/8w1vzhfaa8c8"
#   data {
#     string_value: "The maximum number of metadata supported is 20"
#   }
#   custom_metadata {
#     key: "num_keys"
#     numeric_value: 20
#   }
#   state: STATE_PENDING_PROCESSING
# }

# %%
# Make the request
request = glm.ListChunksRequest(parent=document_resource_name)
list_chunks_response = retriever_service_client.list_chunks(request)
for index, chunks in enumerate(list_chunks_response.chunks):
  print(f'\nChunk # {index + 1}')
  print(f'Resource Name: {chunks.name}')
  # Only ACTIVE chunks can be queried.
  print(f'State: {glm.Chunk.State(chunks.state).name}')
# Out:
# Chunk # 1
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/4z8b1269fayt
# State: STATE_ACTIVE
#
# Chunk # 2
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/6tvx8kgacs0d
# State: STATE_ACTIVE
#
# Chunk # 3
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/8c9p6upvq0m1
# State: STATE_ACTIVE
#
# Chunk # 4
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/bu4fum8h35tc
# State: STATE_ACTIVE
#
# Chunk # 5
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/dmmm49ujud3o
# State: STATE_ACTIVE
#
# Chunk # 6
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/gg9c2o5cclmx
# State: STATE_ACTIVE
#
# Chunk # 7
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/hkju6fmoxocd
# State: STATE_ACTIVE
#
# Chunk # 8
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/hpbpzavvgdof
# State: STATE_ACTIVE
#
# Chunk # 9
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/jxzcxeymxbz5
# State: STATE_ACTIVE
#
# Chunk # 10
# Resource Name: corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/jy8pcszi20h3
# State: STATE_ACTIVE

# %%
# Create a document with a custom display name.
example_document = glm.Document(display_name="How it’s Made: Interacting with Gemini through multimodal prompting")

# Add document metadata.
# Metadata also supports numeric values not specified here
document_metadata = [
    glm.CustomMetadata(key="url", string_value="https://developers.googleblog.com/2023/12/how-its-made-gemini-multimodal-prompting.html")]
example_document.custom_metadata.extend(document_metadata)

# Make the CreateDocument request
# corpus_resource_name is a variable set in the "Create a corpus" section.
create_document_request = glm.CreateDocumentRequest(parent=corpus_resource_name, document=example_document)
create_document_response = retriever_service_client.create_document(create_document_request)

# Set the `document_resource_name` for subsequent sections.
document_resource_name = create_document_response.name
print(create_document_response)

# Chunks - add another webpage from Google for Developers
with(urlopen("https://developers.googleblog.com/2023/12/how-its-made-gemini-multimodal-prompting.html")) as f:
  html = f.read().decode("utf-8")

# Chunk the file using HtmlChunker
chunker = HtmlChunker(
    max_words_per_aggregate_passage=100,
    greedily_aggregate_sibling_nodes=False,
)
passages = chunker.chunk(html)

# Create `Chunk` entities.
chunks = []
for passage in passages:
    chunk = glm.Chunk(data={'string_value': passage})
    chunk.custom_metadata.append(glm.CustomMetadata(key="tags",
                                                    string_list_value=glm.StringList(
                                                        values=["Google For Developers", "Gemini API", "Blog", "Announcement"])))
    chunk.custom_metadata.append(glm.CustomMetadata(key="chunking_strategy",
                                                    string_value="no_aggregate_sibling_nodes"))
    chunk.custom_metadata.append(glm.CustomMetadata(key = "publish_date",
                                                    numeric_value = 20231206))
    chunks.append(chunk)

# Make the request
create_chunk_requests = []
for chunk in chunks:
  create_chunk_requests.append(glm.CreateChunkRequest(parent=document_resource_name, chunk=chunk))
request = glm.BatchCreateChunksRequest(parent=document_resource_name, requests=create_chunk_requests)
response = retriever_service_client.batch_create_chunks(request)
print(response)
# Out:
# name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt"
# display_name: "How it’s Made: Interacting with Gemini through multimodal prompting"
# custom_metadata {
#   key: "url"
#   string_value: "https://developers.googleblog.com/2023/12/how-its-made-gemini-multimodal-prompting.html"
# }
# update_time {
#   seconds: 1720534640
#   nanos: 397824000
# }
# create_time {
#   seconds: 1720534640
#   nanos: 397824000
# }
#
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/es3xonq76mhc"
#   data {
#     string_value: "How it’s Made: Interacting with Gemini through multimodal prompting\n            \n            \n            \n            - Google Developers Blog"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/7k6rhmkzg86f"
#   data {
#     string_value: "Products Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Solutions Events Learn Community Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories Developer Program Blog Search English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/i0hgisme9mhw"
#   data {
#     string_value: "Products More Solutions Events Learn Community More Developer Program Blog Develop Android Chrome ChromeOS Cloud Firebase Flutter Google Assistant Google Maps Platform Google Workspace TensorFlow YouTube Grow Firebase Google Ads Google Analytics Google Play Search Web Push and Notification APIs Earn AdMob Google Ads API Google Pay Google Play Billing Interactive Media Ads Groups Google Developer Groups Google Developer Student Clubs Woman Techmakers Google Developer Experts Tech Equity Collective Programs Accelerator Solution Challenge DevFest Stories All Stories English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/s45hhzcv3aez"
#   data {
#     string_value: "How it’s Made: Interacting with Gemini through multimodal prompting"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/1dk0opf44v90"
#   data {
#     string_value: "DEC 06, 2023"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/4duv3yl7g5qp"
#   data {
#     string_value: "Alexander Chen Creative Director Share Facebook Twitter LinkedIn Mail"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/rgg8avi2bzuv"
#   data {
#     string_value: "Let’s try an experiment. We’ll show this picture to our multimodal model Gemini and ask it to describe what it sees:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/54ic9828jypq"
#   data {
#     string_value: "Tell me what you see Gemini: I see a person\'s right hand. The hand is open with the fingers spread apart."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/9q68b59v73t4"
#   data {
#     string_value: "Ok, let’s try this one:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/qigvltilj5ea"
#   data {
#     string_value: "Gemini: A person knocking on a wooden door."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/xmhe9dlzn1cr"
#   data {
#     string_value: "How about this one?"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/cnzfo6iehdaf"
#   data {
#     string_value: "Gemini: I see a hand with two fingers extended, which is a common symbol for the number two."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/q5kbuni9vew9"
#   data {
#     string_value: "But wait … what if we asked Gemini to reason about all of these images together ?"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/dbw7r46b1k40"
#   data {
#     string_value: "What do you think I\'m doing? Hint: it\'s a game. Gemini: You\'re playing rock, paper, scissors."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/zxa1sppw3fvc"
#   data {
#     string_value: "Nice. What else could we try? Let\'s see if Gemini can notice this pattern:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/9tdmwmm4dpn3"
#   data {
#     string_value: "I’m playing rock paper scissors. Do you notice a pattern in my gameplay? Gemini: You are alternating between rock and scissors."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ew0mdq39xxz4"
#   data {
#     string_value: "Neat, it spotted the pattern! But does Gemini really know how this game works? Let’s try asking:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/hbow5hrtflte"
#   data {
#     string_value: "Hmm ... do you think it\'s a good strategy? Gemini: No, it is not a good strategy. Your opponent will quickly learn your pattern and will be able to win every time. You should try to randomize your choices more."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/kivi0k2v6tnx"
#   data {
#     string_value: "Good advice, Gemini! Okay, for this last one, let’s put your multimodal reasoning capabilities to the test. Here’s your prompt: This is a secret message. What does it say?"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/g122fqo2i9sy"
#   data {
#     string_value: "Can you figure it out? We have gotten Gemini to solve it, but we won’t spoil it by putting the answer in this post. 🙂"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/g5o3k2og2amb"
#   data {
#     string_value: "What is multimodal prompting?"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/h5orcfwyq086"
#   data {
#     string_value: "Everything we did just now is an example of “multimodal prompting.” We’re basically giving Gemini combinations of different modalities — image and text in this case — and having Gemini respond by predicting what might come next. Gemini’s ability to seamlessly combine these modes together enables new possibilities for what you can do."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/igyi7f95v0u4"
#   data {
#     string_value: "In this post, we’ll explore some of the prompting approaches we used in our Hands on with Gemini demo video . We’ll soon be rolling out Gemini for people to try in Google AI Studio, our free, web-based developer tool where you’ll be able to try your own multimodal prompts with Gemini. We’re hoping this guide of starter prompts and ideas helps inspire you to start exploring your own ideas."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/3psr4kk8wak3"
#   data {
#     string_value: "Link to Youtube Video (visible only when JS is disabled)"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/w4q8wglfxb82"
#   data {
#     string_value: "🧮 Spatial reasoning and logic Logic and puzzles are fun way to test Gemini. Let’s try one that requires both left-to-right spatial reasoning and knowledge about our solar system:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/9jaasi98ej7g"
#   data {
#     string_value: "Is this the right order? Consider the distance from the sun and explain your reasoning. Gemini: No, the correct order is Sun, Earth, Saturn. The Sun is the closest to the center of the solar system, followed by the Earth, and then Saturn."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ekt7k59e350s"
#   data {
#     string_value: "Nice! Here’s another, inspired by pinewood derby challenges:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/r7fgilwj1lw9"
#   data {
#     string_value: "Which of these cars is more aerodynamic? The one on the left or the right? Explain why, using specific visual details. Gemini: The car on the right is more aerodynamic. It has a lower profile and a more streamlined shape. The car on the left has a higher profile and a more boxy shape, which makes it less aerodynamic."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/vxuj7gbimuvh"
#   data {
#     string_value: "Image sequences Next, what if we showed Gemini a sequence of images? Let’s see we can show a few still frames from a game of charades and have Gemini guess the movie:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/zlplztvpb7r0"
#   data {
#     string_value: "Guess what movie I\'m acting out. Gemini: The Matrix Nice! But which part specifically? Look at my body movements. Gemini: The part where Neo dodges bullets."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/15jppezgfbom"
#   data {
#     string_value: "🪄 Magic tricks Exploring image sequences really lets you dig into how Gemini reasons over time. Let’s try a classic magic trick."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/a5ypb9x142t1"
#   data {
#     string_value: "Explain what I\'m doing. Gemini: You are holding a coin in your right hand."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/yy36sak1reub"
#   data {
#     string_value: "Where do you think the coin is? Gemini: The coin is in your right hand."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/n6re7cwt2u4m"
#   data {
#     string_value: "Sure, that’s a logical answer given what it’s seen. But let’s pull a sleight of hand as we reveal this next image to Gemini..."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/18yvgeo98em7"
#   data {
#     string_value: "Look here, what happened? Gemini: The coin is gone."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/crsycz3qctyd"
#   data {
#     string_value: "Gemini notices it’s gone. But can it summarize what may have happened?"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/pi6wjnuf7m41"
#   data {
#     string_value: "Summarize what may have happened, step by step, starting with the first image. Gemini: You started with a coin in your right hand. You then made a motion with your hands, and the coin disappeared. 3. You then showed that the coin was gone."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/iswj298mgtvx"
#   data {
#     string_value: "Gemini is leveraging the entire context of this conversation – both text and image – to summarize its answer. Finally, let’s ask:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/b57a35nmnr3n"
#   data {
#     string_value: "Can you explain how it disappeared? Gemini: The coin was palmed."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/1dojtdj2tab"
#   data {
#     string_value: "Gemini makes a really solid guess! But we won’t reveal our secret 🙂."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/b3pe1ygjnnj1"
#   data {
#     string_value: "🔀 Cup shuffling Let’s try a trick that requires memory and logic: the classic ball and cup shuffling game. For this one, we’ll break it down into steps for Gemini. First, let’s establish the basics with these instructions:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/j1tbazksjckm"
#   data {
#     string_value: "Instructions: There are three cups in position 1 (left), position 2 (middle), position 3 (right)."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/5q28lnjsmeyi"
#   data {
#     string_value: "Notice how we came up with a simple format for remembering where the ball is with “empty, empty, ball.” Next, let’s show Gemini two example turns:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/upiduwlxkybt"
#   data {
#     string_value: "Images:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/a0luw1htcuxx"
#   data {
#     string_value: "Swap: 2 and 3 Current state: empty, ball, empty"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/p4gy5csx5fxn"
#   data {
#     string_value: "Images:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/8nromt11bsys"
#   data {
#     string_value: "Swap: 1 and 2 Current state: ball, empty, empty"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ixiul1qfl8wb"
#   data {
#     string_value: "In these two example turns, we’re both showing it what a swap looks like, and how to update the ball position. Now, let’s see if Gemini can generalize to a swap it hasn\'t seen:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/es3g1vzzvyuc"
#   data {
#     string_value: "Images:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/3yz83fstvnht"
#   data {
#     string_value: "Swap:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/z5ez27tsgi8a"
#   data {
#     string_value: "Here\'s Gemini\'s response:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/asf81ef8q25v"
#   data {
#     string_value: "1 and 3 Current state: empty, empty, ball"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/qstfv9yvydi2"
#   data {
#     string_value: "Gemini got it! It looked at these images and correctly inferred that cups 1 and 3 are being swapped. And it reasoned correctly about how to update the ball position. Let’s ask:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/c1hqgyt6kl0w"
#   data {
#     string_value: "Tell me where the ball is and summarize how it got there, in paragraph form. Gemini: The ball is in cup 3. Starting with the ball in cup 3, the first swap was cup 2 and 3. This put the ball in cup 2. The second swap was cup 1 and 2. This put the ball in cup 1. The third swap was cup 1 and 3. This put the ball in cup 3."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/vhrxccpn5mtx"
#   data {
#     string_value: "Not only did Gemini get the answer correctly, it accurately summarized the game history. Of course, it won’t always get this challenge right. Sometimes the fake out move (where you swap two empty cups) seems to trip it up, but sometimes it gets that too. But simple prompts like this make it really fun to rapidly test Gemini. You can change the variables in your prompt, including the order of swaps, and see how it does."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/3kods2ig32dc"
#   data {
#     string_value: "🔨 Tool use If you want to use Gemini in your own apps, you’ll want it to be able to connect to other tools. Let’s try a simple idea where Gemini needs to combine multimodality with tool use: drawing a picture to search for music."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/icss1q5w5xro"
#   data {
#     string_value: "Step 1. Look at this drawing, describe everything in it, and come up with a fun, specific idea for a good musical soundtrack genre, mood, or soundtrack. Step 2. Provide a search query in the form: \"Search [insert query]\" Gemini: The drawing is of a guitar, drums, and an amplifier. There is also a palm tree. The mood is fun, upbeat, and tropical. The genre is reggae. The soundtrack could be used for a movie or TV show set in a tropical location. Search \"Reggae music for a tropical vacation\""
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/uj73gasl4sfi"
#   data {
#     string_value: "Nice! Gemini both reasons about what it sees and then generates a search query you can parse to do a search. It’s like Gemini is acting like a translator for you – but instead of translating between languages, it’s translating modalities – from drawing to music in this case. With multimodal prompting, you can use Gemini to invent your own entirely new translations between different inputs and outputs."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/b68yxav91o7a"
#   data {
#     string_value: "🕹️Game creation What if we tried using Gemini to quickly prototype a multimodal game? Here’s an idea: a geography guessing game where you have to point at a map to make your guess. Let’s start by prompting Gemini with the core idea:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/wc5tfnjr4fc7"
#   data {
#     string_value: "Instructions: Let\'s play a game. Think of a country and give me a clue. The clue must be specific enough that there is only one correct country. I will try pointing at the country on a map."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/3ydpbof8fivy"
#   data {
#     string_value: "Next, let’s give Gemini an example turn of gameplay, showing it how we want it to handle both incorrect and correct answers:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/2idq9jc1do63"
#   data {
#     string_value: "Country: This country is huge island that is mostly covered in ice. (Answer: Greenland) Guess:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/glz7poto1zvx"
#   data {
#     string_value: "I am pointing at the country of Canada *incorrect*"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/7pqjxanwky9l"
#   data {
#     string_value: "Guess:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/4vxucq27mvqf"
#   data {
#     string_value: "I am pointing at the country of Greenland *correct*"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/d6e2pz424fnt"
#   data {
#     string_value: "Let’s give it a go and prompt Gemini to generate a clue:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/dcuy2ogo4pix"
#   data {
#     string_value: "Clue: This country is known for its unique wildlife, including kangaroos and koalas. (Answer: Australia)"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
# ...
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/jqlu6xzj8jni"
#   data {
#     string_value: "My favorite part is scrolling through Gemini’s source code to find the array of motivational emojis it picked for me:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/pxqzg7ipzfcv"
#   data {
#     string_value: "const emojis = [\'🚀\', \'⚡️\', \'🎉\', \'🎊\', \'🥳\', \'🤩\', \'✨\'] ;"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/x6a6vxvgmam5"
#   data {
#     string_value: "👀 A sneak peek"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ouhtq2v4uhjf"
#   data {
#     string_value: "Throughout this post, we’ve been giving Gemini an input, and having Gemini make predictions for what might come next. That\'s basically what prompting is. And our inputs have been multimodal – image and text, combined."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ozv4h90f7pyt"
#   data {
#     string_value: "But so far we\'ve only shown Gemini responding in text. Maybe you’re wondering, can Gemini also respond with a combination of image and text? It can! This is a capability of Gemini called “interleaved text and image generation.” While this feature won’t be ready in the first version of Gemini for people to try, we hope to roll it out soon. Here’s a sneak peek of what’s possible."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/y736p63sbr0t"
#   data {
#     string_value: "Let’s see if we could use Gemini to provide everyday creative inspiration. And let’s try it in a domain that requires a bit of multimodal reasoning ... knitting! 🧶. Similar to our map game above, let\'s provide one example turn of interaction:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/fdd9g60s8j6g"
#   data {
#     string_value: "Give me three ideas for crochet creations I could make with these two colors:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ua5d66bje303"
#   data {
#     string_value: "Colors: I see blue and yellow yarn. Idea 1: How about a cute dog with one yellow ear? Image 1:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/4j2rtbt76emu"
#   data {
#     string_value: "Idea 2: Or how about a jellyfish with a few yellow tentacles? Image 2:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/sfcvrbfuzope"
#   data {
#     string_value: "Idea 3: Or how about a blue cat with a yellow nose? Image 3:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/75xa96u3cpes"
#   data {
#     string_value: "We’re essentially teaching Gemini about how we want each interaction to go: “I’ll take a photo of two balls of yarn, and I expect you (Gemini) to both come up with an idea for something I could make, and generate an image of it.” Now, let’s show it a new pair of yarn colors it hasn\'t yet seen, and see if it can generalize:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/awsgpny97e4d"
#   data {
#     string_value: "Give me three ideas for crochet creations I could make with these two colors:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/zldkn25q6ez5"
#   data {
#     string_value: "Gemini: Colors: I see blue and pink yarn. Idea 1: How about a pig with blue ears? Image 1:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/g6er98fvbsr9"
#   data {
#     string_value: "Idea 2: Or an octopus with pink and blue tentacles? Image 2:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/sh2c7scv6s7n"
#   data {
#     string_value: "Idea 3: Or a bunny with a pink nose? Image 3:"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/olgbfr2i9ed0"
#   data {
#     string_value: "Nice! Gemini correctly reasoned about the new colors (“I see blue and pink yarn”) and generated these ideas and the images in a single, interleaved output of text and image. What Gemini did here is fundamentally different from today’s text-to-image models. It\'s not just passing an instruction to a separate text-to-image model. It sees the image of my actual yarn on my wooden table, truly doing multimodal reasoning about my text and image together ."
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/ytlc93202y39"
#   data {
#     string_value: "What\'s Next? We hope you found this a helpful starter guide to get a sense of what’s possible with Gemini. We’re very excited to roll it out to more people soon so you can explore your own ideas through prompting. Stay tuned!"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/wrbde4cttcjw"
#   data {
#     string_value: "posted in: AI Tutorials How-To Guides Beginner Explore Generative AI Previous Next"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/5u3ruua21xo8"
#   data {
#     string_value: "Related Posts Mobile Web Announcements Bringing the I/O magic to Berlin June 27, 2024 Gemma AI Announcements Fine-tuning Gemma 2 with Keras - and an update from Hugging Face June 27, 2024 Cloud Tutorials Beginner Create smart chips for link previewing in Google Docs Dec. 19, 2023 Gemini AI Tutorials How-To Guides Tune Gemini Pro in Google AI Studio or with the Gemini API March 19, 2024"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/8asefe1mgm1h"
#   data {
#     string_value: "Connect Blog Instagram LinkedIn Twitter YouTube Programs Women Techmakers Google Developer Groups Google Developer Experts Accelerators Google Developer Student Clubs Developer consoles Google API Console Google Cloud Platform Console Google Play Console Firebase Console Actions on Google Console Cast SDK Developer Console Chrome Web Store Dashboard"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }
# chunks {
#   name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/how-its-made-interacting-wi-xtfkq8f4eabt/chunks/1m51ua9u8b8z"
#   data {
#     string_value: "Android Chrome Firebase Google Cloud Platform All products Manage cookies Terms Privacy English English Español (Latam) Bahasa Indonesia 日本語 한국어 Português (Brasil) 简体中文"
#   }
#   custom_metadata {
#     key: "tags"
#     string_list_value {
#       values: "Google For Developers"
#       values: "Gemini API"
#       values: "Blog"
#       values: "Announcement"
#     }
#   }
#   custom_metadata {
#     key: "chunking_strategy"
#     string_value: "no_aggregate_sibling_nodes"
#   }
#   custom_metadata {
#     key: "publish_date"
#     numeric_value: 20231206
#   }
#   state: STATE_PENDING_PROCESSING
# }

# %%
user_query = "What is the purpose of Project IDX?"
results_count = 5

# Add metadata filters for both chunk and document.
chunk_metadata_filter = glm.MetadataFilter(key='chunk.custom_metadata.tags',
                                           conditions=[glm.Condition(
                                              string_value='Google For Developers',
                                              operation=glm.Condition.Operator.INCLUDES)])

# Make the request
# corpus_resource_name is a variable set in the "Create a corpus" section.
request = glm.QueryCorpusRequest(name=corpus_resource_name,
                                 query=user_query,
                                 results_count=results_count,
                                 metadata_filters=[chunk_metadata_filter])
query_corpus_response = retriever_service_client.query_corpus(request)
print(query_corpus_response)
# Out:
# relevant_chunks {
#   chunk_relevance_score: 0.750315785
#   chunk {
#     name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/hpbpzavvgdof"
#     data {
#       string_value: "Project IDX is a browser-based development experience built on Google Cloud and powered by Codey , a foundational AI model trained on code and built on PaLM 2. It’s designed to make it easier to build, manage and deploy full-stack web and multiplatform applications, with popular frameworks and languages. Project IDX is also built on Code OSS , so it should feel familiar no matter what you’re building. A big part of why we’re sharing Project IDX today is we’d love to hear from the broader developer community on what could help you work even faster. In the meantime, here’s a preview of what’s possible today with Project IDX. Get to work quickly, from anywhere At the heart of Project IDX is our conviction that you should be able to develop from anywhere, on any device, with the full fidelity of local development. Every Project IDX workspace has the full capabilities of a Linux-based VM, paired with the universal access that comes with being hosted in the cloud, in a datacenter near you."
#     }
#     custom_metadata {
#       key: "tags"
#       string_list_value {
#         values: "Google For Developers"
#         values: "Project IDX"
#         values: "Blog"
#         values: "Announcement"
#       }
#     }
#     custom_metadata {
#       key: "chunking_strategy"
#       string_value: "greedily_aggregate_sibling_nodes"
#     }
#     custom_metadata {
#       key: "publish_date"
#       numeric_value: 20230808
#     }
#     create_time {
#       seconds: 1720534621
#       nanos: 396643000
#     }
#     update_time {
#       seconds: 1720534629
#       nanos: 832457000
#     }
#     state: STATE_ACTIVE
#   }
# }
# relevant_chunks {
#   chunk_relevance_score: 0.732504129
#   chunk {
#     name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/bu4fum8h35tc"
#     data {
#       string_value: "Help from AI We spend a lot of time writing code, and recent advances in AI have created big opportunities to make that time more productive. With Project IDX, we’re exploring how Google’s innovations in AI — including the Codey and PaLM 2 models powering Studio Bot in Android Studio , Duet in Google Cloud and more – can help you not only write code faster, but also write higher-quality code. Currently, Project IDX has smart code completion, an assistive chatbot, and contextual code actions like “add comments” and “explain this code”. Our AI capabilities are in their very early days, and we’re working on making IDX AI even better at helping you as you work."
#     }
#     custom_metadata {
#       key: "tags"
#       string_list_value {
#         values: "Google For Developers"
#         values: "Project IDX"
#         values: "Blog"
#         values: "Announcement"
#       }
#     }
#     custom_metadata {
#       key: "chunking_strategy"
#       string_value: "greedily_aggregate_sibling_nodes"
#     }
#     custom_metadata {
#       key: "publish_date"
#       numeric_value: 20230808
#     }
#     create_time {
#       seconds: 1720534621
#       nanos: 396643000
#     }
#     update_time {
#       seconds: 1720534629
#       nanos: 832457000
#     }
#     state: STATE_ACTIVE
#   }
# }
# relevant_chunks {
#   chunk_relevance_score: 0.73074156
#   chunk {
#     name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/ygr31a3ebd51"
#     data {
#       string_value: "Let’s build Project IDX together We shared how we think Project IDX can start to make multiplatform app development better, along with some strides we’ve started making in these areas. But we are just at the beginning of this journey to improve the end-to-end development workflow, and we can only make good on this vision with your help. So with that, we’d like to share an early version of Project IDX with you — rough edges and all — to iterate on what’s working well and what could be even better for your app team’s workflow. To join us on our journey, visit our website to sign up and be one of the first to try Project IDX. As for what’s next, we’re continuously working on adding new capabilities and addressing your feedback. We’re already working on new collaboration features, as we know how important those are in this hybrid work world, as well as deeper framework integrations and more personalized/contextual AI. Please share your feature requests with us as well!"
#     }
#     custom_metadata {
#       key: "tags"
#       string_list_value {
#         values: "Google For Developers"
#         values: "Project IDX"
#         values: "Blog"
#         values: "Announcement"
#       }
#     }
#     custom_metadata {
#       key: "chunking_strategy"
#       string_value: "greedily_aggregate_sibling_nodes"
#     }
#     custom_metadata {
#       key: "publish_date"
#       numeric_value: 20230808
#     }
#     create_time {
#       seconds: 1720534621
#       nanos: 396643000
#     }
#     update_time {
#       seconds: 1720534629
#       nanos: 832457000
#     }
#     state: STATE_ACTIVE
#   }
# }
# relevant_chunks {
#   chunk_relevance_score: 0.724811912
#   chunk {
#     name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/hkju6fmoxocd"
#     data {
#       string_value: "These days, getting an app from zero to production – especially one that works well across mobile, web, and desktop platforms – can feel like building a Rube Goldberg machine. You’ve got to navigate an endless sea of complexity, duct-taping together a tech stack that\'ll help you bootstrap, compile, test, deploy, and monitor your apps. While Google’s been working on making multiplatform app development easier for years – from Angular and Flutter to Google Cloud and Firebase – it feels like there’s even more we can do to make the entire multiplatform app development workflow faster and more frictionless . So several months ago, a few of us got together and started experimenting. And today, we’re excited to share a very early look at our experiment, which we’re calling Project IDX ."
#     }
#     custom_metadata {
#       key: "tags"
#       string_list_value {
#         values: "Google For Developers"
#         values: "Project IDX"
#         values: "Blog"
#         values: "Announcement"
#       }
#     }
#     custom_metadata {
#       key: "chunking_strategy"
#       string_value: "greedily_aggregate_sibling_nodes"
#     }
#     custom_metadata {
#       key: "publish_date"
#       numeric_value: 20230808
#     }
#     create_time {
#       seconds: 1720534621
#       nanos: 396643000
#     }
#     update_time {
#       seconds: 1720534629
#       nanos: 832457000
#     }
#     state: STATE_ACTIVE
#   }
# }
# relevant_chunks {
#   chunk_relevance_score: 0.719401479
#   chunk {
#     name: "corpora/google-for-developers-blog-iiiol6kl1i8x/documents/introducing-project-idx-an--1dk0qr1hsqx3/chunks/jxzcxeymxbz5"
#     data {
#       string_value: "Import your existing app, or start something new Project IDX lets you import your existing projects from GitHub so you can pick up right where you left off. You can also create new projects, with pre-baked templates for popular frameworks, including Angular, Flutter, Next.js, React, Svelte, Vue, and languages such as JavaScript, Dart, and (coming soon) Python, Go, and more. We’re also actively working to add first-class support for more project types and frameworks. If you have any suggestions, we’d love your feedback on which stacks to support."
#     }
#     custom_metadata {
#       key: "tags"
#       string_list_value {
#         values: "Google For Developers"
#         values: "Project IDX"
#         values: "Blog"
#         values: "Announcement"
#       }
#     }
#     custom_metadata {
#       key: "chunking_strategy"
#       string_value: "greedily_aggregate_sibling_nodes"
#     }
#     custom_metadata {
#       key: "publish_date"
#       numeric_value: 20230808
#     }
#     create_time {
#       seconds: 1720534621
#       nanos: 396643000
#     }
#     update_time {
#       seconds: 1720534629
#       nanos: 832457000
#     }
#     state: STATE_ACTIVE
#   }
# }
